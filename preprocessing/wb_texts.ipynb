# %%
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from wordcloud import WordCloud
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans, SpectralClustering

# %%
df = pd.read_csv('wb_data.csv')

# %%
df = pd.read_csv('wb_data.csv')
df = df[df['num_feedbacks'] > 100]
df = df[~(df['material'].isna() | df['equipment'].isna() | df['description'].isna())]
text_length = []
for i in range(len(df['description'].values)):
    text_length.append(len(df['description'].values[i]))
df['text_length'] = text_length

# %%
stop_words = set(stopwords.words('russian') + ['не', 'только', 'так', 'и', 'но', 'но и',
                                               'так и', 'также', 'а также', 'не только'])
lemmatizer = WordNetLemmatizer()

# %%
def preprocess(text):
    text = list(filter(str.isalpha, word_tokenize(text.lower())))
    text = list(lemmatizer.lemmatize(word) for word in text)
    text = list(word for word in text if word not in stop_words)
    return ' '.join(text)
texts['text'] = texts.apply(lambda row: preprocess(row.description), axis=1)

# %%
from wordcloud import WordCloud

def draw_wordcloud(texts, max_words=1000, width=1000, height=500):
    wordcloud = WordCloud(background_color='white', max_words=max_words,
                          width=width, height=height)

    joint_texts = ' '.join(list(texts))
    wordcloud.generate(joint_texts)
    return wordcloud.to_image()

# %%
vectorizer = TfidfVectorizer(min_df = 200)
X = vectorizer.fit_transform(texts['text'])

model = KMeans(n_clusters = 4)
pred = model.fit_predict(X)

# %%
draw_wordcloud(texts[pred == 0].text)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x500>

# %%
draw_wordcloud(texts[pred == 1].text)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x500>

# %%
df['cluster'] = pred

# %%
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
sent_dict = pd.read_table('sentdict.txt').T

def get_sentiment(sentence):
    sentence = sentence.split()
    total = 0
    for word in sentence:
        if word in sent_dict.columns:
            total += sent_dict[word].values[0]
    return total / len(sentence)

df['sentiment'] = texts['text'].apply(get_sentiment)

# %%
df.to_csv('df_after_texts.csv')

# %%
df.to_csv('df_after_text.csv', index = False, encoding = 'utf-8-sig')

# %%
df = pd.read_csv('final_df.csv')
df
# Out:
#              id                                               name  \
# 0     251773651                           Грызунок пульт для зубов
# 1      90705358                   Мягкая игрушка Сяо геншин импакт
# 2      73090209                   Мягкая игрушка Ворон Бравл Старз
# 3      43079352  Червячки деревянные, сортер для малышей магнит...
# 4     217742416  Силиконовый прорезыватель грызунок пульт для з...
# ...         ...                                                ...
# 5131   72078711                       Игровой набор "Лето на даче"
# 5132  164443245             Among Us мини фигурки 1 шт во флоупаке
# 5133  138787230  Картонный домик раскраска, большой развивающий...
# 5134  165234550  Развивающие игрушки книжка шуршалка для новоро...
# 5135  235149602  Монтессори игрушки из дерева/Развивающий магни...
#
#                   type                                        description  \
# 0        Прорезыватели  СУПЕР НОВИНКА!!! Теперь можно больше не прятат...
# 1       Мягкие игрушки  Мягкая игрушка Геншин Импакт! Игрушки выполнен...
# 2       Мягкие игрушки  Мягкие игрушки выполнены в виде персонажей из ...
# 3              Сортеры  Дополнительный набор из 10 червячков для магни...
# 4        Прорезыватели  Силиконовый прорезыватель-пульт от для малышей...
# ...                ...                                                ...
# 5131       Головоломки  Игровой набор представлен в 6-ти вариантах: "П...
# 5132   Фигурки-игрушки  Мини-фигурки Амонг Ас - идеальный подарок для ...
# 5133  Домики для детей  Картонный игровой развивающий Домик-раскраска ...
# 5134    Книжки-игрушки  Большая развивающая книжка шуршалка с хвостика...
# 5135           Сортеры  Развивающая деревянная игра для малышей . Доск...
#
#       is_verified                                              color  \
# 0            True                                             черный
# 1           False                                              синий
# 2           False                                             черный
# 3            True       зеленый, красный, голубой, оранжевый, желтый
# 4           False                                    глубокий черный
# ...           ...                                                ...
# 5131         True                                                NaN
# 5132         True                             красный, желтый, синий
# 5133         True                                                NaN
# 5134         True  фиолетовый меланж, голубой меланж, пурпурно-кр...
# 5135        False                                              синий
#
#                brand  has_video  photo_count country  ... supplier_rating  \
# 0            KIDSLAB       True           16   Китай  ...             4.9
# 1      Плюшевый друг      False            1   Китай  ...             4.8
# 2          LoveBeary      False            1   Китай  ...             4.8
# 3        Danila.toys       True            6   Китай  ...             4.9
# 4        LIN FACTORY      False           13     NaN  ...             4.8
# ...              ...        ...          ...     ...  ...             ...
# 5131           Крона       True            9  Россия  ...             4.8
# 5132        Among us       True            8   Китай  ...             4.8
# 5133        Brauberg       True           21  Россия  ...             4.9
# 5134          Zeimas      False           19   Китай  ...             4.9
# 5135  Красная поляна       True           15   Китай  ...             4.8
#
#      item_rating  num_feedbacks  quantity   price  \
# 0            4.9          49270      2469   25500
# 1            4.8           2918         9   46800
# 2            4.7           2548        18   46800
# 3            4.9           4014      2162   17100
# 4            4.9           2267       586   26100
# ...          ...            ...       ...     ...
# 5131         5.0            821       709   61800
# 5132         4.7            956       845   28500
# 5133         4.8           4046       439  157700
# 5134         4.9           1800       491   66600
# 5135         4.9            160        42   48600
#
#                                                     img  text_length cluster  \
# 0     https://basket-16.wbbasket.ru/vol2517/part2517...         1119       1
# 1     https://basket-05.wbbasket.ru/vol907/part90705...          511       2
# 2     https://basket-05.wbbasket.ru/vol730/part73090...          934       1
# 3     https://basket-03.wbbasket.ru/vol430/part43079...          816       1
# 4     https://basket-14.wbbasket.ru/vol2177/part2177...         2000       1
# ...                                                 ...          ...     ...
# 5131  https://basket-05.wbbasket.ru/vol720/part72078...         1025       1
# 5132  https://basket-11.wbbasket.ru/vol1644/part1644...         1810       1
# 5133  https://basket-10.wbbasket.ru/vol1387/part1387...         1588       1
# 5134  https://basket-11.wbbasket.ru/vol1652/part1652...         1180       1
# 5135  https://basket-15.wbbasket.ru/vol2351/part2351...         1890       1
#
#       sentiment  rating
# 0      0.074952     0.0
# 1      0.017000     0.0
# 2      0.028663     0.0
# 3      0.065792     0.0
# 4      0.034376     1.0
# ...         ...     ...
# 5131   0.019000     0.0
# 5132   0.036136     0.0
# 5133   0.044276     1.0
# 5134   0.017517     0.0
# 5135   0.012880     1.0
#
# [5136 rows x 22 columns]
